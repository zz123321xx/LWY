# 學生22   66   87   93   97   55
# 學生23   77   75   62   76   72
# 學生24   89   68   91   77   91
# 學生25   82   88  100   69   64
# 學生26   72   96   79   76   96
# 學生27   92   72   75   83   53
# 學生28   98   61   95   59   86
# 學生29   74   75   62   68   83
# 學生30   82  100   66   67   93
# 學生31   50   90   89   84   87
# 學生32   78   69   79   54   50
# 學生33   69   93   80   81   65
# 學生34   61   53   71   79   52
# 學生35  100   52   94   59   58
# 學生36   91   93   78   50   85
# 學生37   76   67   86   76   86
# 學生38   97   59   98   60   98
# 學生39   87   62   87   58   59
# 學生40   59   51   95   74   76
# 學生41   77   56   99  100   79
# 學生42   88   64   87   95   53
# 學生43   79   66   67   96   79
# 學生44   81   96   81   62   88
# 學生45   64   82   64   79   57
# 學生46   63   74   54   84   85
# 學生47   65   62   78   93   92
# 學生48   53   99   52   84   96
# 學生49   55   62   92   78   54
# 學生50   92   93   55   87   92

# %%
s = df1.loc['學生1']
less_than_60_series = s[s<60]
#取出不及格的科目
failing_subjects = less_than_60_series.index.tolist()
failing_subjects
#取出不及格科目的分數
failing_scores = less_than_60_series.tolist()
failing_scores
#建立一個Series,值要轉換為字串,如果有多個值則用逗號分隔
failing_scores_str = ','.join(map(str, failing_scores))
failing_subjects_str = ','.join(failing_subjects)
pd.Series([failing_scores_str, failing_subjects_str], index=['分數', '不及格科目'])
# Out:
# 分數       53,58
# 不及格科目    國文,自然
# dtype: object

# %%
def apply_statistics(s):
    less_than_60_series = s[s<60]
    #不及格科目數量
    failing_subjects_count = less_than_60_series.count()
    #取出不及格的科目
    failing_subjects = less_than_60_series.index.tolist()
    
    #取出不及格科目的分數
    failing_scores = less_than_60_series.tolist()
    
    #建立一個Series,值要轉換為字串,如果有多個值則用逗號分隔
    failing_scores_str = ','.join(map(str, failing_scores))
    failing_subjects_str = ','.join(failing_subjects)
    return pd.Series([failing_subjects_count,failing_subjects_str,failing_scores_str], index=['不及格科目數量', '不及格科目', '分數'])


df2 = df1.apply(apply_statistics, axis=1)
df2
# Out:
#       不及格科目數量     不及格科目        分數
# 學生
# 學生1         2     國文,自然     53,58
# 學生2         1        數學        59
# 學生3         1        數學        50
# 學生4         0
# 學生5         2     英文,社會     51,51
# 學生6         1        社會        52
# 學生7         1        數學        52
# 學生8         0
# 學生9         2     英文,數學     56,50
# 學生10        0
# 學生11        0
# 學生12        0
# 學生13        0
# 學生14        0
# 學生15        1        社會        50
# 學生16        0
# 學生17        1        國文        55
# 學生18        1        英文        58
# 學生19        0
# 學生20        1        英文        59
# 學生21        1        社會        59
# 學生22        1        社會        55
# 學生23        0
# 學生24        0
# 學生25        0
# 學生26        0
# 學生27        1        社會        53
# 學生28        1        自然        59
# 學生29        0
# 學生30        0
# 學生31        1        國文        50
# 學生32        2     自然,社會     54,50
# 學生33        0
# 學生34        2     英文,社會     53,52
# 學生35        3  英文,自然,社會  52,59,58
# 學生36        1        自然        50
# 學生37        0
# 學生38        1        英文        59
# 學生39        2     自然,社會     58,59
# 學生40        2     國文,英文     59,51
# 學生41        1        英文        56
# 學生42        1        社會        53
# 學生43        0
# 學生44        0
# 學生45        1        社會        57
# 學生46        1        數學        54
# 學生47        0
# 學生48        2     國文,數學     53,52
# 學生49        2     國文,社會     55,54
# 學生50        1        數學        55

# %%
#df要和df2合併
df_merged = pd.concat([df, df2], axis=1)
df_merged
# Out:
